# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn.preprocessing as prp
import statsmodels.api as sm
from sklearn.feature_selection import mutual_info_classif
from sklearn.ensemble import ExtraTreesClassifier,RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold,GridSearchCV,train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
df=pd.read_csv("D:\Open IIT DATA\Open-IIT-Data-analytics\Question_datasets\Train_data.csv") #reading test data
df.head(10)
# Out:
#       id  acousticness  danceability  energy explicit  instrumentalness  key  \
# 0   2015         0.949         0.235  0.0276       No           0.92700    5
# 1  15901         0.855         0.456  0.4850       No           0.08840    4
# 2   9002         0.827         0.495  0.4990       No           0.00000    0
# 3   6734         0.654         0.643  0.4690       No           0.10800    7
# 4  15563         0.738         0.705  0.3110       No           0.00000    5
# 5  14384         0.898         0.498  0.4420       No           0.00319   10
# 6    954         0.259         0.620  0.7580       No           0.00132    5
# 7   5930         0.124         0.879  0.6280      Yes           0.00000    1
# 8  11900         0.149         0.697  0.1840      Yes           0.00000    2
# 9  14498         0.470         0.587  0.5660       No           0.00000    9
#
#    liveness  loudness   mode release_date  speechiness    tempo  valence  \
# 0    0.5130   -27.398  Major   01-01-1947       0.0381  110.838   0.0398
# 1    0.1510   -10.046  Major   13-11-2020       0.0437  152.066   0.8590
# 2    0.4010    -8.009  Minor   01-01-1950       0.0474  108.004   0.7090
# 3    0.2180   -15.917  Major   30-04-1974       0.0368   83.636   0.9640
# 4    0.3220   -12.344  Major   01-01-1973       0.0488  117.260   0.7850
# 5    0.0974    -9.481  Major   01-01-1968       0.0337  109.619   0.3550
# 6    0.4160    -8.183  Major   13-11-1942       0.0343  119.258   0.9120
# 7    0.0661    -6.668  Minor   01-01-2005       0.2640  150.105   0.7210
# 8    0.0763   -23.303  Minor   01-01-1945       0.9330  133.997   0.6130
# 9    0.0644    -9.932  Major   01-01-1999       0.0276   76.054   0.5290
#
#    year  duration-min popularity
# 0  1947           3.0   very low
# 1  2020           2.4        low
# 2  1950           2.6   very low
# 3  1974           2.4        low
# 4  1973           3.4    average
# 5  1968           2.6        low
# 6  1942           2.4   very low
# 7  2005           3.5    average
# 8  1945           1.6   very low
# 9  1999           7.7       high

# %%
df["release_date"]=pd.to_datetime(df["release_date"]) #converting str to timestamp

# %%
#creating new columns with encoded categorical features (mode,explicit)
le1=prp.LabelEncoder()
le2=prp.LabelEncoder()
le1.fit(df["explicit"])
le2.fit(df["mode"])
df["explicit_coded"]=le1.transform(df["explicit"])
df["mode_coded"]=le2.transform(df["mode"])

# %%
#encoding the target variable (popularity)

def encoder(row): # function to encode popularity
    if row["popularity"]=="very low":
        return 1
    if row["popularity"]=="low":
        return 2
    if row["popularity"]=="average":
        return 3
    if row["popularity"]=="high":
        return 4
    if row["popularity"]=="very high":
        return 5

df["popularity_code"]=df.apply(lambda row : encoder(row),axis=1) #creating new column for coded popularity

# %%
#calculating covariences
covar=list()
for i in df.columns:
    filt=i=="explicit" or i=="release_date" or i=="mode" or i=="popularity" or i=="popularity_code" or i=="id" or i=='Day' or i=='Num_days'
    if not filt :
        covar.append(df[i].cov(df["popularity_code"]))
colms=list()
for i in df.columns:
    filt=i=="explicit" or i=="release_date" or i=="mode" or i=="popularity" or i=="popularity_code" or i=="id" or i=='Day'or i=='Num_days'
    if not filt :
        colms.append(i)
covariences = pd.DataFrame({'Features':colms,'Covarience_wrt_popularity':covar}) # covarience dataframe

# %%
#plotting covariences
fg,axs=plt.subplots(figsize=(20,10))
sns.barplot(ax=axs,x='Features',y='Covarience_wrt_popularity',data=covariences,saturation=1)
axs.set_xlabel('''
                   Features''' , size=16)
axs.set_ylabel('''Covarience_wrt_popularity
                                           ''', size=16)
axs.set_title('''Covariences between popularity and features
                                                             ''',size=24)
plt.grid(True)
plt.savefig("D:\Open IIT DATA\Open-IIT-Data-analytics\Diagrams\covariences.png") #saving the file

# %%
#calculating pearson corelation coefficient
correl=list()
for i in df.columns:
    filt=i=="explicit" or i=="release_date" or i=="mode" or i=="popularity" or i=="popularity_code" or i=="id"or i=='Day' 
    if not filt :
        correl.append(df[i].corr(df["popularity_code"]))
colms=list()
for i in df.columns:
    filt=i=="explicit" or i=="release_date" or i=="mode" or i=="popularity" or i=="popularity_code" or i=="id"or i=='Day'
    if not filt :
        colms.append(i)
corelation = pd.DataFrame({'Features':colms,'Corelations_wrt_popularity':correl}) # corelation dataframe

# %%
#plotting corelations
fg,axs=plt.subplots(figsize=(20,10))
sns.barplot(ax=axs,x='Features',y='Corelations_wrt_popularity',data=corelation,saturation=1)
axs.set_xlabel('''
                   Features''' , size=16)
axs.set_ylabel('''Corelations_wrt_popularity
                                           ''', size=16)
axs.set_title('''Corelations between popularity and features
                                                             ''',size=24)
plt.grid(True)
plt.savefig("D:\Open IIT DATA\Open-IIT-Data-analytics\Diagrams\corelation.png") #saving the file

# %%
def fucnc(row):
    if row["release_date"].weekday()<5:
        return 0
    else:
        return 1
df["weekend"]=df.apply(lambda row:fucnc(row),axis=1)

# %%
fig=plt.figure(figsize=(14,8))
sns.catplot(y="popularity_code",x="weekend",data=df,kind='bar',ci=None)

# %%
a=list()
for i in range(5):
    a.append(df.loc[df['weekend']==1]['popularity_code'].value_counts()[i+1]/df['weekend'].value_counts()[1])

# %%
b=list()
for i in range(5):
    b.append(df.loc[df['weekend']==0]['popularity_code'].value_counts()[i+1]/df['weekend'].value_counts()[0])

# %%
proba=pd.DataFrame({"popularity":df['popularity'].value_counts().keys(),"probability":a,"Weekend":[1]*5})
probb=pd.DataFrame({"popularity":df['popularity'].value_counts().keys(),"probability":b,"Weekend":[0]*5})

# %%
prob=pd.concat([proba,probb])
prob
# Out:
#   popularity  probability  Weekend
# 0   very low     0.292559        1
# 1        low     0.279704        1
# 2    average     0.233346        1
# 3       high     0.176081        1
# 4  very high     0.018309        1
# 0   very low     0.255797        0
# 1        low     0.248447        0
# 2    average     0.239441        0
# 3       high     0.222981        0
# 4  very high     0.033333        0

# %%
fig=plt.figure(figsize=(14,8))
sns.barplot(y="probability",x="popularity",data=prob,hue="Weekend")
# Out:
# <AxesSubplot:xlabel='popularity', ylabel='probability'>

# %%
def func(row):
    day_name= ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday','Sunday']
    return day_name[row['release_date'].weekday()]
df["Day"]=df.apply(lambda row : func(row),axis=1)

# %%
sns.catplot(x='Day',y='popularity_code',order=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday','Sunday'],kind='bar',data=df,aspect=2,ci=None)

# %%
# Number of days b/w release date and 01/01/2022
from datetime import datetime
ref_date=datetime(2022,1,1)
def days(row):
    delta=ref_date-row['release_date']
    return delta.days
df["Num_days"]=df.apply(lambda row : days(row),axis=1)
df
# Out:
#           id  acousticness  danceability  energy explicit  instrumentalness  \
# 0       2015        0.9490        0.2350  0.0276       No          0.927000
# 1      15901        0.8550        0.4560  0.4850       No          0.088400
# 2       9002        0.8270        0.4950  0.4990       No          0.000000
# 3       6734        0.6540        0.6430  0.4690       No          0.108000
# 4      15563        0.7380        0.7050  0.3110       No          0.000000
# ...      ...           ...           ...     ...      ...               ...
# 12222  15343        0.0408        0.8090  0.8010       No          0.000000
# 12223   1701        0.9120        0.4510  0.2400       No          0.000002
# 12224   3351        0.3280        0.5510  0.5640       No          0.002950
# 12225   8879        0.1220        0.0608  0.9390       No          0.991000
# 12226   9711        0.0380        0.3890  0.7680      Yes          0.000000
#
#        key  liveness  loudness   mode  ...  valence  year  duration-min  \
# 0        5     0.513   -27.398  Major  ...  0.03980  1947           3.0
# 1        4     0.151   -10.046  Major  ...  0.85900  2020           2.4
# 2        0     0.401    -8.009  Minor  ...  0.70900  1950           2.6
# 3        7     0.218   -15.917  Major  ...  0.96400  1974           2.4
# 4        5     0.322   -12.344  Major  ...  0.78500  1973           3.4
# ...    ...       ...       ...    ...  ...      ...   ...           ...
# 12222    1     0.353    -5.461  Major  ...  0.74400  2014           3.4
# 12223    1     0.175   -14.014  Major  ...  0.70100  1959           2.0
# 12224    2     0.352    -9.298  Minor  ...  0.89000  1984           2.5
# 12225    1     0.912   -26.324  Major  ...  0.00558  2017           3.1
# 12226    1     0.119    -4.765  Major  ...  0.33400  2020           3.1
#
#        popularity  explicit_coded  mode_coded popularity_code  weekend  \
# 0        very low               0           0               1        0
# 1             low               0           0               2        0
# 2        very low               0           1               1        1
# 3             low               0           0               2        0
# 4         average               0           0               3        0
# ...           ...             ...         ...             ...      ...
# 12222     average               0           0               3        0
# 12223   very high               0           0               5        0
# 12224         low               0           1               2        1
# 12225        high               0           0               4        0
# 12226        high               1           0               4        0
#
#              Day  Num_days
# 0      Wednesday     27394
# 1         Friday       414
# 2         Sunday     26298
# 3        Tuesday     17413
# 4         Monday     17897
# ...          ...       ...
# 12222    Tuesday      2916
# 12223   Thursday     23011
# 12224     Sunday     13880
# 12225     Friday      1583
# 12226     Friday       526
#
# [12227 rows x 23 columns]

# %%
columns=list()
for i in df.columns:
    filt=i=='id' or i=='explicit' or i=='mode' or i=='release_date' or i=='popularity' or i=='weekend' or i=='Day'or i=='Num_days'
    if not filt:
        columns.append(i)
covar=df.loc[:,columns].cov() # covarience data frame

# %%
fig=plt.figure(figsize=(14,8))
sns.heatmap(covar,annot=True)
# Out:
# <AxesSubplot:>

# %%
columns=columns[:-1]
correl=df.loc[:,columns].corr() #correlation
fig=plt.figure(figsize=(14,8))
sns.heatmap(correl,cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %%
#p-value calculation
x=sm.OLS(df['popularity_code'],df.loc[:,columns]).fit()
p=x.pvalues
columns
# Out:
# ['acousticness',
#  'danceability',
#  'energy',
#  'instrumentalness',
#  'key',
#  'liveness',
#  'loudness',
#  'speechiness',
#  'tempo',
#  'valence',
#  'year',
#  'duration-min',
#  'explicit_coded',
#  'mode_coded']

# %%
p_values=pd.DataFrame({'Features': p.keys(),'p_vals':p.values}) #data frame

# %%
fig=plt.figure(figsize=(22,10))
sns.barplot(y='p_vals',x='Features',data=p_values)
plt.plot(np.arange(0,15,1),np.ones(15)*0.05)

# %%
col=list()
for i in df.columns:
    filt=i=='id' or i=='explicit' or i=='mode' or i=='release_date' or i=='popularity' or i=='Day'
    if not filt:
        col.append(i)
num_df=df.loc[:,col] #working dataframe

# %%
# Feature selection
X=num_df.drop('popularity_code',axis=1)
y=num_df['popularity_code']
Best_features=ExtraTreesClassifier()
Best_features.fit(X,y)
Tree_scores=pd.DataFrame({'Features':X.columns,'Scores':Best_features.feature_importances_})

# %%
Tree_scores.nlargest(16,'Scores')
# Out:
#             Features    Scores
# 15          Num_days  0.186593
# 10              year  0.170603
# 0       acousticness  0.070060
# 3   instrumentalness  0.064120
# 6           loudness  0.058111
# 2             energy  0.057295
# 7        speechiness  0.053692
# 1       danceability  0.050856
# 11      duration-min  0.050228
# 5           liveness  0.050166
# 9            valence  0.049274
# 8              tempo  0.048598
# 4                key  0.043965
# 13        mode_coded  0.017643
# 14           weekend  0.016482
# 12    explicit_coded  0.012312

# %%
mutual=mutual_info_classif(X,y)
mutual_scores=pd.DataFrame({'Features':X.columns,'Scores':mutual})
mutual_scores.nlargest(16,'Scores')
# Out:
#             Features    Scores
# 15          Num_days  0.616934
# 10              year  0.556317
# 0       acousticness  0.138237
# 6           loudness  0.117097
# 3   instrumentalness  0.082521
# 2             energy  0.076009
# 11      duration-min  0.070557
# 8              tempo  0.068633
# 7        speechiness  0.047189
# 12    explicit_coded  0.044555
# 1       danceability  0.028906
# 5           liveness  0.014727
# 9            valence  0.011290
# 13        mode_coded  0.002712
# 4                key  0.000000
# 14           weekend  0.000000

# %%
corelation.nlargest(14,'Corelations_wrt_popularity')
# Out:
#             Features  Corelations_wrt_popularity
# 10              year                    0.635493
# 6           loudness                    0.413219
# 2             energy                    0.327218
# 12    explicit_coded                    0.260153
# 1       danceability                    0.220554
# 8              tempo                    0.076751
# 13        mode_coded                    0.039218
# 4                key                    0.014269
# 9            valence                   -0.005329
# 11      duration-min                   -0.009381
# 5           liveness                   -0.103116
# 7        speechiness                   -0.122614
# 3   instrumentalness                   -0.317268
# 0       acousticness                   -0.407964

# %%
#From above analysis let's remove weekend,key,mode_coded,valence
X=X.drop(['weekend','key','mode_coded','valence'],axis=1)

# %%
#remove the  highly corelated columns
l=list()
for i in range(len(X.columns)):
    for j in range(i):
        if abs(X.corr().iloc[i,j])>0.75:
            l.append((X.columns[i],X.columns[j]))
l
# Out:
# [('loudness', 'energy'), ('Num_days', 'year')]

# %%
X=X.drop(['energy','year'],axis=1) #droping one of each highly corelated columns

# %%
l=list(X.columns)
l.remove('explicit_coded')
X.hist(column=l,figsize=(14,8),bins=50)
plt.show()

# %%
X["duration-min"]=np.log(X["duration-min"])
X["tempo"]=np.sqrt(X["tempo"])
X["speechiness"]=np.sqrt(X["speechiness"])
X['liveness']=np.log(X['liveness'])

# %%
l=list(X.columns)
l.remove('explicit_coded')
X.hist(column=l,figsize=(14,8),bins=50)
plt.show()

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,y,train_size=0.7,random_state=4901) #train and test sets

# %%
log_class=LogisticRegression()
grid={'C':10.0**np.arange(-2,3),'penalty':['l1','l2']}
cv=KFold(n_splits=5,random_state=None,shuffle=False)

# %%
clf=GridSearchCV(log_class,grid,cv=cv,n_jobs=-1,scoring='f1_macro')
clf.fit(X_train,Y_train)
# Out:
# c:\python\python39\lib\site-packages\sklearn\model_selection\_search.py:918: UserWarning: One or more of the test scores are non-finite: [       nan 0.41749213        nan 0.41890212        nan 0.42253306
#         nan 0.41784055        nan 0.41778902]
#   warnings.warn(
# GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'C': array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02]),
#                          'penalty': ['l1', 'l2']},
#              scoring='f1_macro')

# %%
Y_pred=clf.predict(X_test)
print(confusion_matrix(Y_test,Y_pred))
print(accuracy_score(Y_test,Y_pred))
# Out:
# [[707  23   7 230   0]
#  [309 439 160  33   0]
#  [ 96 248 263 254   0]
#  [ 22  93 103 563   0]
#  [  2   4   1 112   0]]
# 0.5374761515399291

# %%
X=num_df.drop('year',axis=1)

# %%
X=num_df.drop('popularity_code',axis=1)
Y=num_df['popularity_code']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,y,train_size=0.7,random_state=4901) #train and test sets

# %%
log_class=LogisticRegression()
grid={'C':10.0**np.arange(-2,3),'penalty':['l1','l2']}
cv=KFold(n_splits=5,random_state=None,shuffle=False)
